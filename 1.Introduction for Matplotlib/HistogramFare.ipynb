# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('train.csv')
plt.hist(df["Fare"],bins=15,color="lightgreen",edgecolor="black")
plt.xlabel("Fare")
plt.ylabel("Frequency")
plt.title("Histogram of Fare")
plt.grid(True,linestyle="--")
